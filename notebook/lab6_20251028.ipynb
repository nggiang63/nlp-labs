# %% [markdown]
# # 20251028

# %% [markdown]
# # RNN

# %%
# !pip install bigdl
# Out:
# Collecting bigdl
#   Downloading bigdl-2.4.0-py3-none-manylinux1_x86_64.whl (1.6 kB)
# Collecting bigdl-nano==2.4.0
#   Downloading bigdl_nano-2.4.0-py3-none-manylinux2010_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.1 MB/s eta 0:00:00a 0:00:010m
# Collecting bigdl-chronos==2.4.0
#   Downloading bigdl_chronos-2.4.0-py3-none-manylinux1_x86_64.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.2/352.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting bigdl-orca==2.4.0
#   Downloading bigdl_orca-2.4.0-py3-none-manylinux1_x86_64.whl (20.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.4/20.4 MB 491.9 kB/s eta 0:00:0000:0100:02
# Collecting bigdl-friesian==2.4.0
#   Downloading bigdl_friesian-2.4.0-py3-none-manylinux1_x86_64.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.6/171.6 kB 406.1 kB/s eta 0:00:00a 0:00:01
# Collecting bigdl-serving==2.4.0
#   Downloading bigdl_serving-2.4.0-py2.py3-none-any.whl (21 kB)
# Collecting pandas<=1.3.5,>=1.0.5
#   Downloading pandas-1.3.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 319.2 kB/s eta 0:00:0000:0100:01
# Collecting scikit-learn<=1.0.2,>=0.22.0
#   Downloading scikit_learn-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 128.8 kB/s eta 0:00:0000:0100:06
# Collecting sigfig
#   Downloading sigfig-1.3.19-py3-none-any.whl (10 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Collecting protobuf==3.19.5
#   Downloading protobuf-3.19.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 323.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages (from bigdl-nano==2.4.0->bigdl) (25.0)
# Collecting intel-openmp
#   Downloading intel_openmp-2025.3.0-py2.py3-none-manylinux_2_28_x86_64.whl (74.3 MB)
#      ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/74.3 MB 243.7 kB/s eta 0:04:44
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "/usr/lib/python3.10/http/client.py", line 466, in read
#     s = self.fp.read(amt)
#   File "/usr/lib/python3.10/socket.py", line 717, in readinto
#     return self._sock.recv_into(b)
#   File "/usr/lib/python3.10/ssl.py", line 1307, in recv_into
#     return self.read(nbytes, buffer)
#   File "/usr/lib/python3.10/ssl.py", line 1163, in read
#     return self._sslobj.read(len, buffer)
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/commands/install.py", line 419, in run
#     requirement_set = resolver.resolve(
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/resolvelib/resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/resolvelib/resolvers.py", line 373, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/resolvelib/resolvers.py", line 213, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/resolvelib/resolvers.py", line 204, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/resolvelib/resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/resolvelib/structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 297, in __init__
#     super().__init__(
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 162, in __init__
#     self.dist = self._prepare()
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 231, in _prepare
#     dist = self._prepare_distribution()
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 308, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/operations/prepare.py", line 491, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/operations/prepare.py", line 536, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/operations/prepare.py", line 166, in unpack_url
#     file = get_http_url(
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/operations/prepare.py", line 107, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/network/download.py", line 147, in __call__
#     for chunk in chunks:
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/cli/progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_internal/network/utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 560, in read
#     with self._error_catcher():
#   File "/usr/lib/python3.10/contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/home/giangnt/Downloads/NLP_DL/nlp-labs/bigdl_venv/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import com.intel.analytics.bigdl.dllib.tensor._
import com.intel.analytics.bigdl.dllib.keras._
import com.intel.analytics.bigdl.dllib.utils._
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import com.intel.analytics
#
# ModuleNotFoundError: No module named 'com'

# %%
val x = Tensor[Float](1, 10, 5).rand()

# %%
val rnn = LSTM[Float](3)
